# %% [markdown]
# # Ford GoBike Exploration
# ## by Giulio Tommasino

# %% [markdown]
# ## Investigation Overview
#
# In this analysis, I would like to figure  when and where are most trips taken, and what kind of characteristics are in these locations and time periods.
# I would also figure out the differences between costumers and subscribers and if there are differences between the characteristics (gender, age) and duration of trips.
#
# ## Dataset Overview
#
# Data consists of info about trips taken by service's members, their types, their age, their gender, stations of starting and ending trips, duration of trips etc.
#
# 1) Duration of the rent for each bike
# <br>
# 2) Start and end time
# <br>
# 3) An ID to identify the station (both start and end)
# <br>
# 4) Latitude and longitude of the station  ( start and end)
# <br>
# 5) tude and longitude of the station ( start and end)
# <br>
# 6) ID to identify each bike
# <br>
# 7) Wheter the user has subscription or nothe user has subscription or not
# <br>
# 8) The gender of the user
# <br>
# 9) Year of birth of the user
# <br>
# 10) The gender of the user
# <br>
# There are 183412 rows and 16 columns

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df1 = pd.read_csv('cleaned.csv')

# %% [markdown]
# ## Most common Gender
#
# Males are the most common users of ford go bike are males. They are the 75% of the total, with female at the 23% and other genders are the 2% of the total

# %%
genders.plot(kind='pie', figsize = (7,5),autopct ='%1.0f%%', title = 'Distribution of Genders');

# %% [markdown]
# ## Distance Traveled and Ride duration
#
# 1) The distance travel chart shows that short trips are the most common: The mean length of a ride is 1.48km
#
#
# 2) Most of the rides are less than 20 minutes long, with an average of 11 minutes

# %%
plt.hist(data = df1, x = 'distance', bins = np.arange(0,6,0.2))

plt.title('Distance Traveled', fontsize = 15)
plt.xlabel('Distance (km)')
plt.ylabel('Number of trips');

# %%
plt.hist(data = df1, x = 'duration', bins = np.arange(0, 100, 5))

plt.title("Ride Duration ",  fontsize=14)
plt.xlabel('Duration  (minutes)')
plt.ylabel('Number of rides');

# %% [markdown]
# ## Weekday usage and day usage
#
# 1) Subscribers use the service more often on Monday through Friday, for the customer there is not this difference, since each day has approximatly the same number of trips. It is clear to see that the subscribers use the service a lot more than customer.
#
#
# 2) For costumers the period between 15-23 was the one with the more usage of the service, while for subscribers there isn't such period, instead there is a periodicity of 5 days every 7 days. This is in accordance of the previous chart.

# %%
g = sb.catplot(data=df1, x='start_time_weekday', col="user_type", kind='count', order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], color = 'blue')
g.set_axis_labels("Weekday", "Number of Bike Trips")
g.set_titles("{col_name}")
g.fig.suptitle('Weekday Usage of the Bikeshare System per User Type', y=1.03, fontsize=14, fontweight='semibold');

# %%
g = sb.catplot(data=df1, x='day', col="user_type", kind='count',color = 'blue', sharey = False)
g.set_axis_labels("day", "Number rides")
g.set_titles("{col_name}")
g.fig.suptitle('Usage of the Bikeshare system per User type and Gender', y=1.03, fontsize=14, fontweight='semibold');

# %% [markdown]
# ## Average distance between subscribers and costumers
#
# Costumers take longer rides than subscribers. The mean distance for subscribers is 1.46 km , and the mean for costumers is 1.67 km.

# %%
h = df1.groupby('user_type')['distance'].mean().plot(kind='barh', figsize=(13,8))
plt.xlabel('Distance (km)', fontsize = 13)
plt.ylabel('User Type', fontsize = 13)
plt.title('Average Distance for User type', fontsize = 15);

# %% [markdown]
# ## Usage of the Bikeshare system per User type and Gender
#
# This chart shows how each gender follow a similar pattern .

# %%
g = sb.catplot(data=df1, x='start_time_weekday', col="user_type", hue='member_gender', kind='count', sharey = False, order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
g.set_axis_labels("Weekday", "Number rides")
g._legend.set_title('Gender')
g.set_titles("{col_name}")
g.fig.suptitle('Usage of the Bikeshare system per User type and Gender', y=1.03, fontsize=14, fontweight='semibold');
